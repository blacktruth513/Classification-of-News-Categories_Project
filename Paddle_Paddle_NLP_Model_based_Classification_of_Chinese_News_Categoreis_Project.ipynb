# %% [markdown]
# <a href="https://colab.research.google.com/github/blacktruth513/Paddle-Paddle-NLP-Model_based_Classification-of-Chinese-News-Categoreis_Project/blob/main/Paddle_Paddle_NLP_Model_based_Classification_of_Chinese_News_Categoreis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# # 개인 프로젝트 1
#
# ---
#
# #<center> **< RoBert 모델 적용 딥러닝 기반 중국 신문 주제 분류  프로젝트>** </center>
#
# ---
# <br>
#
# 1.  프로젝트 주제 및 목적
# <br>
#
# 2. 프로젝트 문제 정의
# <br>
#
# 3. 데이터 선정 이유 및 소개
# <br>
# <br>
#
# 4. 딥러닝 프레임워크 및 사전학습 모델 소개
# <br>
#
# 5. 모델링(데이터 전처리 프로세스 포함)
# <br>
#
# 6. 프로젝트 결론 및 향후 개선점
# <br>

# %% [markdown]
# # 1 프로젝트 주제 및 목적

# %% [markdown]
# ## 1-1 프로젝트 주제
#
# - 주제 : Robert 사전모델(Pre-trained Model)을 적용한 Paddle-Paddle 딥러닝 프레임워크 기반 중국 신문 주제 분류 프로젝트

# %% [markdown]
# ##1-2 프로젝트 목적
#
#
# - 중국어 자연어에 대한 이해력을 바탕으로, 언어 모델에 대한 심화된 이해력을 갖추고 다양한 딥러닝 프레임워크를 사용함으로써, 딥러닝 기술 활용 역량 강화를 목표로 한다.

# %% [markdown]
# # 2 프로젝트 문제 정의
#
# - 프로젝트 가설 : 주어진 데이터의 특성 변수를 통해 신문 기사 카테고리(타겟 변수)의 다중 분류 값을  예측할 수 있다.
# <br>
# <br>
# - 프로젝트 예상 결과 : 딥러닝 모델링을 통해 다중 분류의 값을 학습시키고 정확도를 측정한다.

# %% [markdown]
# # 3 데이터 선정 이유 및 소개

# %% [markdown]
# ![sina_weibo.jfif](data:image/jpeg;base64,...)
#
#  - 중국 SNS 플랫폼인 新浪微博(시나 웨이보) 출처 데이터로서, "과학기술, 체육, 엔터테인먼트, 정치, 사회, 교육 등 14개의 카테고리의 주제 기사가 포함된 약 83만개(학습/검증), 84,000개(테스트)의 데이터로 구성되어 있다.  주제 다중 분류를 수행하는 본 프로젝트에 데이터로 사용하기에 적절하다고 판단해 해당 데이터를 사용하여 프로젝트를 수행했다.

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# upload data(txt > df)
df_train = pd.read_table('/content/drive/MyDrive/AI_Bootcamp/Project1_Data/train.txt', sep='\t', header=None)
df_valid = pd.read_table('/content/drive/MyDrive/AI_Bootcamp/Project1_Data/dev.txt', sep='\t', header=None)
df_test = pd.read_table('/content/drive/MyDrive/AI_Bootcamp/Project1_Data/test.txt', sep='\t', header=None)

# %%
df_train.columns = ['text', 'label']
df_valid.columns = ['text', 'label']
df_test.columns = ['text']

print(df_train)
print(df_valid)
print(df_test)
# Out:
#                              text label
# 0                 网易第三季度业绩低于分析师预期    科技
# 1       巴萨1年前地狱重现这次却是天堂 再赴魔鬼客场必翻盘    体育
# 2              美国称支持向朝鲜提供紧急人道主义援助    时政
# 3                增资交银康联 交行夺参股险商首单    股票
# 4                    午盘：原材料板块领涨大盘    股票
# ...                           ...   ...
# 752466     天津女排奇迹之源竟在场边 他是五冠王真正核心    体育
# 752467       北电网络专利拍卖推迟：可能分拆6部分拍卖    科技
# 752468  Spirit AeroSystems债券发行价确定    股票
# 752469    陆慧明必发火线：法兰克福无胜 曼联国米顺利过关    彩票
# 752470       首破万元 索尼46寸全新LED液晶特价促    科技
#
# [752471 rows x 2 columns]
#                            text label
# 0      网民市民集体幻想中奖后如果你中了9000万怎么办    彩票
# 1                   PVC期货有望5月挂牌    财经
# 2              午时三刻新作《幻神录―宿命情缘》    游戏
# 3          欧司朗LLFY网络提供一站式照明解决方案    家居
# 4         试探北京楼市向何方：排不完的队　涨不够的价    房产
# ...                         ...   ...
# 79995  王大雷看国足比赛预测比分我觉得是2-0或者3-1    体育
# 79996   克雷扎回归猛龙势如破竹希尔遭驱逐太阳惨败51分    体育
# 79997           王建宙将与台商共创4G网络商机    科技
# 79998      普京突访食品超市做调查不满高价猪肉(图)    时政
# 79999        高空俯视女明星性感乳沟(组图)(7)    时尚
#
# [80000 rows x 2 columns]
#                               text
# 0          北京君太百货璀璨秋色 满100省353020元
# 1                教育部：小学高年级将开始学习性知识
# 2            专业级单反相机 佳能7D单机售价9280元
# 3              星展银行起诉内地客户 银行强硬客户无奈
# 4           脱离中国的实际 强压人民币大幅升值只能是梦想
# ...                            ...
# 83594        Razer杯DotA精英挑战赛8月震撼登场
# 83595              经济数据好转吹散人民币贬值预期
# 83596         抵押率抵押物双控政策 刘明康支招房产贷款
# 83597  8000万像素 利图发布Aptus-II 12数码后背
# 83598          教育部公布33个国家万余所正规学校名单
#
# [83599 rows x 1 columns]

# %%
# EDA
# 학습 + 검증 데이터 병합 
df_total = pd.concat([df_train, df_valid], axis=0)

# %%
# 타겟 데이터 분류 카테고리 확인 
df_total['label'].value_counts()
# Out:
# 科技    162245
# 股票    153949
# 体育    130982
# 娱乐     92228
# 时政     62867
# 社会     50541
# 教育     41680
# 财经     36963
# 家居     32363
# 游戏     24283
# 房产     19922
# 时尚     13335
# 彩票      7598
# 星座      3515
# Name: label, dtype: int64

# %%
# 데이터 문서 길이 통계 분석 // 데이터 문서 최대 길이 = 48
df_total['text'].map(len).describe()
# Out:
# count    832471.000000
# mean         19.388112
# std           4.097139
# min           2.000000
# 25%          17.000000
# 50%          20.000000
# 75%          23.000000
# max          48.000000
# Name: text, dtype: float64

# %%
df_test['text'].map(len).describe()
# Out:
# count    83599.000000
# mean        19.815022
# std          3.883845
# min          3.000000
# 25%         17.000000
# 50%         20.000000
# 75%         23.000000
# max         84.000000
# Name: text, dtype: float64

# %%
df_train.to_csv('df_train.csv', sep='\t', index=False)
df_valid.to_csv('df_valid.csv', sep='\t', index=False)
df_test.to_csv('df_test.csv', sep='\t', index=False)

# %%
# !pip install --upgrade paddlepaddle-gpu 
# !pip install --upgrade paddlenlp

# %%
import math
import numpy as np
import os
import collections
from functools import partial
import random
import time
import inspect
import importlib
from tqdm import tqdm

# paddle-paddle
import paddle
import paddle.nn as nn
import paddle.nn.functional as F
from paddle.io import IterableDataset, Dataset
from paddlenlp.datasets import MapDataset
from paddlenlp.transformers import RobertaForSequenceClassification, RobertaTokenizer #pre-trained model 
from paddle.utils.download import get_path_from_url
import paddlenlp as ppnlp
from paddlenlp.data import JiebaTokenizer, Pad, Stack, Tuple, Vocab
from paddlenlp.datasets import DatasetBuilder
from paddle.dataset.common import md5file
from paddlenlp.transformers import LinearDecayWithWarmup

# %% [markdown]
# # 4 딥러닝 프레임워크 및 사전학습 모델 소개

# %% [markdown]
# ![paddle.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ![bert_image.png](data:image/png;base64,...)

# %%
# 전이학습(Pre-Trained Model)
MODEL_NAME = "roberta-wwm-ext-large"
model = ppnlp.transformers.RobertaForSequenceClassification.from_pretrained(MODEL_NAME, num_classes=14) # 此次分类任务为14分类任务，故num_classes设置为14
# Robert 모델을 통한 토크나이징 실시
tokenizer = ppnlp.transformers.RobertaTokenizer.from_pretrained(MODEL_NAME)
# Out:
# [2021-10-21 13:28:34,941] [    INFO] - Already cached /root/.paddlenlp/models/roberta-wwm-ext-large/roberta_chn_large.pdparams
# [2021-10-21 13:28:41,954] [    INFO] - Already cached /root/.paddlenlp/models/roberta-wwm-ext-large/vocab.txt

# %%
labels = list(df_train.label.unique())
print(labels)
# Out:
# ['科技', '体育', '时政', '股票', '娱乐', '教育', '家居', '财经', '房产', '社会', '游戏', '彩票', '星座', '时尚']

# %% [markdown]
# # 5 모델링(데이터 전처리 프로세스 포함)

# %% [markdown]
# ##  5-1 데이터 전처리 및 모델링 준비 도식화
# ![paddle flow.png](data:image/png;base64,...)

# %%
# 데이터셋 / 데이터 변수 자료형 저장 함수
class NewsData(DatasetBuilder):
    splits = {
        'train': 'df_train.csv',  
        'valid': 'df_valid.csv'}
    
    def _get_data(self, mode, **kwargs):
        filename = self.splits[mode]
        return filename

    def _read(self, filename):
        #load data
        with open(filename, 'r', encoding='utf-8') as f:
            head = None
            for line in f:
                data = line.strip().split("\t")   
                if not head:
                    head = data
                else:
                    text, label = data
                    yield {"text": text, "label": label} 
    def get_labels(self):
        return labels

# %%
# 데이터셋 함수화
def load_dataset(name=None,
                 data_files=None,
                 splits=None,
                 lazy=None,
                 **kwargs):
   
    reader_cls = NewsData  
    print(reader_cls)
    if not name:
        reader_instance = reader_cls(lazy=lazy, **kwargs)
    else:
        reader_instance = reader_cls(lazy=lazy, name=name, **kwargs)

    datasets = reader_instance.read_datasets(data_files=data_files, splits=splits)
    
    return datasets

# %%
df_train, df_valid = load_dataset(splits=["train", "valid"])
# Out:
# <class '__main__.NewsData'>

# %%
# 딥러닝 프레임워크용 데이터 변형
def create_dataloader(dataset,
                      mode='train',
                      batch_size=1,
                      batchify_fn=None,
                      trans_fn=None):
    if trans_fn:
        dataset = dataset.map(trans_fn)

    shuffle = True if mode == 'train' else False

    # 데이터 셔플 
    if mode == 'train':
        batch_sampler = paddle.io.DistributedBatchSampler(
            dataset=dataset, batch_size=batch_size, shuffle=True)
    else:
        batch_sampler = paddle.io.BatchSampler(
            dataset=dataset, batch_size=batch_size, shuffle=shuffle)

    dataloader = paddle.io.DataLoader(
        dataset=dataset,
        batch_sampler=batch_sampler,
        #return_list=True,
        collate_fn=batchify_fn)
    
    return dataloader

def convert_example(example, tokenizer, max_seq_length=48, is_test=False):
    qtconcat = example['text']
    encoded_inputs = tokenizer(text=qtconcat, max_seq_len=max_seq_length)  
    input_ids = encoded_inputs["input_ids"]
    token_type_ids = encoded_inputs["token_type_ids"]

    if not is_test:
        label = np.array([example["label"]], dtype="int64")
        return input_ids, token_type_ids, label
    else:
        return input_ids, token_type_ids

# %%
# 배치사이즈 
batch_size = 16
max_seq_length = 48

trans_func = partial(
    convert_example,
    tokenizer=tokenizer,
    max_seq_length=max_seq_length)

batchify_fn = lambda samples, fn=Tuple(
    Pad(axis=0, pad_val=tokenizer.pad_token_id),  # input_ids
    Pad(axis=0, pad_val=tokenizer.pad_token_type_id),  # token_type_ids
    Stack()  # labels
): [data for data in fn(samples)]

# 훈련 데이터셋
train_data_loader = create_dataloader(
    df_train,
    mode='train',
    batch_size=batch_size,
    batchify_fn=batchify_fn,
    trans_fn=trans_func)

# 검증 데이터셋
dev_data_loader = create_dataloader(
    df_valid,
    mode='dev',
    batch_size=batch_size,
    batchify_fn=batchify_fn,
    trans_fn=trans_func)

# %%
#하이퍼파라미터, 로스함수, 최적화 함수 정의
epochs = 1
learning_rate = 2e-5

# # 学习率预热比例
# warmup_proportion = 0.1
# # 权重衰减系数，类似模型正则项策略，避免模型过拟合
# weight_decay = 0.01
# num_training_steps = len(train_data_loader) * epochs
# lr_scheduler = LinearDecayWithWarmup(learning_rate, num_training_steps, warmup_proportion)

optimizer = paddle.optimizer.AdamW(
    learning_rate=learning_rate,
    parameters=model.parameters())

criterion = paddle.nn.loss.CrossEntropyLoss()

metric = paddle.metric.Accuracy()

# %%
# 성능 평가 함수 
@paddle.no_grad()
def evaluate(model, criterion, metric, data_loader):
    model.eval()
    metric.reset()
    losses = []
    for batch in data_loader:
        input_ids, token_type_ids, labels = batch
        logits = model(input_ids, token_type_ids)
        loss = criterion(logits, labels)
        losses.append(loss.numpy())
        correct = metric.compute(logits, labels)
        metric.update(correct)
        accu = metric.accumulate()
    print("eval loss: %.5f, accu: %.5f" % (np.mean(losses), accu)) 
    model.train()
    metric.reset()
    return accu

# %%
# 랜덤시드 고정
seed = 1024 
random.seed(1024)
np.random.seed(1024)
paddle.seed(1024)

# %% [markdown]
# ## 5-2 모델 학습

# %%
# 학습/검증 데이터 적용 모델링
save_dir = "checkpoint"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

pre_accu=0
accu=0
global_step = 0
for epoch in range(1, epochs + 1):
    for step, batch in enumerate(train_data_loader, start=1):
        input_ids, segment_ids, labels = batch
        logits = model(input_ids, segment_ids)
        loss = criterion(logits, labels) # 로스함수
        probs = F.softmax(logits, axis=1) # 소프트맥스 다중분류함수
        correct = metric.compute(probs, labels)
        metric.update(correct)
        acc = metric.accumulate()

        global_step += 1
        if global_step % 100 == 0 :
            print("global step %d, epoch: %d, batch: %d, loss: %.5f, acc: %.5f" % (global_step, epoch, step, loss, acc))
        loss.backward()
        optimizer.step()
        #lr_scheduler.step()
        optimizer.clear_grad()
        
    # epch 종료시 검증 데이터 평가
    accu = evaluate(model, criterion, metric, dev_data_loader)
    print(accu)
    
    if accu > pre_accu:
        save_param_path = os.path.join(save_dir, 'model_state.pdparams')  
        paddle.save(model.state_dict(), save_param_path)
        pre_accu=accu    
tokenizer.save_pretrained(save_dir)
# Out:
# global step 100, epoch: 1, batch: 100, loss: 1.08459, acc: 0.73125
# global step 200, epoch: 1, batch: 200, loss: 0.06354, acc: 0.80688
# global step 300, epoch: 1, batch: 300, loss: 0.27519, acc: 0.83333
# global step 400, epoch: 1, batch: 400, loss: 0.69796, acc: 0.84984
# global step 500, epoch: 1, batch: 500, loss: 0.92420, acc: 0.85913
# global step 600, epoch: 1, batch: 600, loss: 0.51070, acc: 0.86583
# global step 700, epoch: 1, batch: 700, loss: 0.07620, acc: 0.87125
# global step 800, epoch: 1, batch: 800, loss: 0.02231, acc: 0.87813
# global step 900, epoch: 1, batch: 900, loss: 0.36633, acc: 0.88222
# global step 1000, epoch: 1, batch: 1000, loss: 0.24343, acc: 0.88606
# global step 1100, epoch: 1, batch: 1100, loss: 0.05819, acc: 0.88858
# global step 1200, epoch: 1, batch: 1200, loss: 0.49443, acc: 0.89104
# global step 1300, epoch: 1, batch: 1300, loss: 0.08104, acc: 0.89236
# global step 1400, epoch: 1, batch: 1400, loss: 0.51495, acc: 0.89509
# global step 1500, epoch: 1, batch: 1500, loss: 0.02644, acc: 0.89667
# global step 1600, epoch: 1, batch: 1600, loss: 0.08512, acc: 0.89762
# global step 1700, epoch: 1, batch: 1700, loss: 0.11079, acc: 0.89779
# global step 1800, epoch: 1, batch: 1800, loss: 0.10053, acc: 0.89882
# global step 1900, epoch: 1, batch: 1900, loss: 0.28992, acc: 0.89964
# global step 2000, epoch: 1, batch: 2000, loss: 0.19353, acc: 0.90034
# global step 2100, epoch: 1, batch: 2100, loss: 0.56454, acc: 0.90167
# global step 2200, epoch: 1, batch: 2200, loss: 0.28960, acc: 0.90244
# global step 2300, epoch: 1, batch: 2300, loss: 0.39721, acc: 0.90326
# global step 2400, epoch: 1, batch: 2400, loss: 0.03885, acc: 0.90367
# global step 2500, epoch: 1, batch: 2500, loss: 0.47993, acc: 0.90415
# global step 2600, epoch: 1, batch: 2600, loss: 0.28429, acc: 0.90512
# global step 2700, epoch: 1, batch: 2700, loss: 0.15892, acc: 0.90558
# global step 2800, epoch: 1, batch: 2800, loss: 0.44485, acc: 0.90612
# global step 2900, epoch: 1, batch: 2900, loss: 0.04672, acc: 0.90670
# global step 3000, epoch: 1, batch: 3000, loss: 0.05118, acc: 0.90694
# global step 3100, epoch: 1, batch: 3100, loss: 0.19810, acc: 0.90774
# global step 3200, epoch: 1, batch: 3200, loss: 0.20535, acc: 0.90865
# global step 3300, epoch: 1, batch: 3300, loss: 0.02603, acc: 0.90920
# global step 3400, epoch: 1, batch: 3400, loss: 0.03780, acc: 0.90960
# global step 3500, epoch: 1, batch: 3500, loss: 0.14619, acc: 0.91007
# global step 3600, epoch: 1, batch: 3600, loss: 0.08231, acc: 0.91056
# global step 3700, epoch: 1, batch: 3700, loss: 0.37387, acc: 0.91088
# global step 3800, epoch: 1, batch: 3800, loss: 0.09519, acc: 0.91135
# global step 3900, epoch: 1, batch: 3900, loss: 0.31265, acc: 0.91149
# global step 4000, epoch: 1, batch: 4000, loss: 0.13105, acc: 0.91186
# global step 4100, epoch: 1, batch: 4100, loss: 0.12790, acc: 0.91220
# global step 4200, epoch: 1, batch: 4200, loss: 0.06365, acc: 0.91249
# global step 4300, epoch: 1, batch: 4300, loss: 0.13553, acc: 0.91285
# global step 4400, epoch: 1, batch: 4400, loss: 0.09689, acc: 0.91320
# global step 4500, epoch: 1, batch: 4500, loss: 0.71756, acc: 0.91375
# global step 4600, epoch: 1, batch: 4600, loss: 0.04199, acc: 0.91421
# global step 4700, epoch: 1, batch: 4700, loss: 0.56249, acc: 0.91459
# global step 4800, epoch: 1, batch: 4800, loss: 0.03410, acc: 0.91490
# global step 4900, epoch: 1, batch: 4900, loss: 0.17824, acc: 0.91526
# global step 5000, epoch: 1, batch: 5000, loss: 0.37654, acc: 0.91549
# global step 5100, epoch: 1, batch: 5100, loss: 0.19150, acc: 0.91563
# global step 5200, epoch: 1, batch: 5200, loss: 0.09104, acc: 0.91591
# global step 5300, epoch: 1, batch: 5300, loss: 0.13877, acc: 0.91606
# global step 5400, epoch: 1, batch: 5400, loss: 0.74668, acc: 0.91648
# global step 5500, epoch: 1, batch: 5500, loss: 0.10717, acc: 0.91672
# global step 5600, epoch: 1, batch: 5600, loss: 0.15347, acc: 0.91700
# global step 5700, epoch: 1, batch: 5700, loss: 0.24873, acc: 0.91719
# global step 5800, epoch: 1, batch: 5800, loss: 0.47105, acc: 0.91754
# global step 5900, epoch: 1, batch: 5900, loss: 0.03422, acc: 0.91787
# global step 6000, epoch: 1, batch: 6000, loss: 0.01939, acc: 0.91827
# global step 6100, epoch: 1, batch: 6100, loss: 0.58779, acc: 0.91847
# global step 6200, epoch: 1, batch: 6200, loss: 0.26856, acc: 0.91862
# global step 6300, epoch: 1, batch: 6300, loss: 0.55258, acc: 0.91874
# global step 6400, epoch: 1, batch: 6400, loss: 0.01569, acc: 0.91906
# global step 6500, epoch: 1, batch: 6500, loss: 0.53017, acc: 0.91922
# global step 6600, epoch: 1, batch: 6600, loss: 0.06299, acc: 0.91949
# global step 6700, epoch: 1, batch: 6700, loss: 0.11219, acc: 0.91969
# global step 6800, epoch: 1, batch: 6800, loss: 0.24589, acc: 0.91994
# global step 6900, epoch: 1, batch: 6900, loss: 0.04957, acc: 0.92017
# global step 7000, epoch: 1, batch: 7000, loss: 0.11602, acc: 0.92038
# global step 7100, epoch: 1, batch: 7100, loss: 0.24712, acc: 0.92059
# global step 7200, epoch: 1, batch: 7200, loss: 0.13843, acc: 0.92088
# global step 7300, epoch: 1, batch: 7300, loss: 0.04398, acc: 0.92110
# global step 7400, epoch: 1, batch: 7400, loss: 0.10488, acc: 0.92145
# global step 7500, epoch: 1, batch: 7500, loss: 0.14643, acc: 0.92143
# global step 7600, epoch: 1, batch: 7600, loss: 0.46819, acc: 0.92175
# global step 7700, epoch: 1, batch: 7700, loss: 0.57826, acc: 0.92192
# global step 7800, epoch: 1, batch: 7800, loss: 0.04067, acc: 0.92212
# global step 7900, epoch: 1, batch: 7900, loss: 0.05686, acc: 0.92241
# global step 8000, epoch: 1, batch: 8000, loss: 0.55519, acc: 0.92270
# global step 8100, epoch: 1, batch: 8100, loss: 0.39507, acc: 0.92296
# global step 8200, epoch: 1, batch: 8200, loss: 0.39587, acc: 0.92308
# global step 8300, epoch: 1, batch: 8300, loss: 0.14606, acc: 0.92316
# global step 8400, epoch: 1, batch: 8400, loss: 0.46127, acc: 0.92317
# global step 8500, epoch: 1, batch: 8500, loss: 0.08720, acc: 0.92329
# global step 8600, epoch: 1, batch: 8600, loss: 0.11517, acc: 0.92357
# global step 8700, epoch: 1, batch: 8700, loss: 0.13454, acc: 0.92376
# global step 8800, epoch: 1, batch: 8800, loss: 0.33222, acc: 0.92388
# global step 8900, epoch: 1, batch: 8900, loss: 0.79872, acc: 0.92409
# global step 9000, epoch: 1, batch: 9000, loss: 0.39358, acc: 0.92426
# global step 9100, epoch: 1, batch: 9100, loss: 0.31923, acc: 0.92431
# global step 9200, epoch: 1, batch: 9200, loss: 0.09532, acc: 0.92433
# global step 9300, epoch: 1, batch: 9300, loss: 0.21063, acc: 0.92452
# global step 9400, epoch: 1, batch: 9400, loss: 0.01976, acc: 0.92466
# global step 9500, epoch: 1, batch: 9500, loss: 0.16784, acc: 0.92493
# global step 9600, epoch: 1, batch: 9600, loss: 0.11665, acc: 0.92507
# global step 9700, epoch: 1, batch: 9700, loss: 0.26148, acc: 0.92528
# global step 9800, epoch: 1, batch: 9800, loss: 0.16076, acc: 0.92545
# global step 9900, epoch: 1, batch: 9900, loss: 0.14108, acc: 0.92554
# global step 10000, epoch: 1, batch: 10000, loss: 0.09554, acc: 0.92565
# global step 10100, epoch: 1, batch: 10100, loss: 0.15669, acc: 0.92569
# global step 10200, epoch: 1, batch: 10200, loss: 0.11157, acc: 0.92588
# global step 10300, epoch: 1, batch: 10300, loss: 0.02253, acc: 0.92596
# global step 10400, epoch: 1, batch: 10400, loss: 0.07539, acc: 0.92608
# global step 10500, epoch: 1, batch: 10500, loss: 0.59239, acc: 0.92615
# global step 10600, epoch: 1, batch: 10600, loss: 0.36463, acc: 0.92613
# global step 10700, epoch: 1, batch: 10700, loss: 0.01950, acc: 0.92629
# global step 10800, epoch: 1, batch: 10800, loss: 0.35178, acc: 0.92642
# global step 10900, epoch: 1, batch: 10900, loss: 0.19337, acc: 0.92666
# global step 11000, epoch: 1, batch: 11000, loss: 0.34244, acc: 0.92678
# global step 11100, epoch: 1, batch: 11100, loss: 0.36204, acc: 0.92688
# global step 11200, epoch: 1, batch: 11200, loss: 0.04907, acc: 0.92690
# global step 11300, epoch: 1, batch: 11300, loss: 0.09689, acc: 0.92696
# global step 11400, epoch: 1, batch: 11400, loss: 0.03964, acc: 0.92698
# global step 11500, epoch: 1, batch: 11500, loss: 0.32568, acc: 0.92714
# global step 11600, epoch: 1, batch: 11600, loss: 0.22887, acc: 0.92725
# global step 11700, epoch: 1, batch: 11700, loss: 0.42102, acc: 0.92730
# global step 11800, epoch: 1, batch: 11800, loss: 0.23573, acc: 0.92745
# global step 11900, epoch: 1, batch: 11900, loss: 0.04788, acc: 0.92756
# global step 12000, epoch: 1, batch: 12000, loss: 0.47750, acc: 0.92753
# global step 12100, epoch: 1, batch: 12100, loss: 0.13499, acc: 0.92762
# global step 12200, epoch: 1, batch: 12200, loss: 0.26013, acc: 0.92766
# global step 12300, epoch: 1, batch: 12300, loss: 0.33051, acc: 0.92780
# global step 12400, epoch: 1, batch: 12400, loss: 0.13943, acc: 0.92795
# global step 12500, epoch: 1, batch: 12500, loss: 0.15989, acc: 0.92797
# global step 12600, epoch: 1, batch: 12600, loss: 0.20912, acc: 0.92810
# global step 12700, epoch: 1, batch: 12700, loss: 0.22330, acc: 0.92812
# global step 12800, epoch: 1, batch: 12800, loss: 0.19752, acc: 0.92818
# global step 12900, epoch: 1, batch: 12900, loss: 0.01450, acc: 0.92825
# global step 13000, epoch: 1, batch: 13000, loss: 0.78176, acc: 0.92834
# global step 13100, epoch: 1, batch: 13100, loss: 0.01293, acc: 0.92841
# global step 13200, epoch: 1, batch: 13200, loss: 0.12950, acc: 0.92849
# global step 13300, epoch: 1, batch: 13300, loss: 0.25353, acc: 0.92857
# global step 13400, epoch: 1, batch: 13400, loss: 0.48666, acc: 0.92867
# global step 13500, epoch: 1, batch: 13500, loss: 0.32079, acc: 0.92872
# global step 13600, epoch: 1, batch: 13600, loss: 0.03483, acc: 0.92881
# global step 13700, epoch: 1, batch: 13700, loss: 0.09900, acc: 0.92889
# global step 13800, epoch: 1, batch: 13800, loss: 0.31149, acc: 0.92895
# global step 13900, epoch: 1, batch: 13900, loss: 0.06521, acc: 0.92902
# global step 14000, epoch: 1, batch: 14000, loss: 0.66347, acc: 0.92912
# global step 14100, epoch: 1, batch: 14100, loss: 0.14383, acc: 0.92923
# global step 14200, epoch: 1, batch: 14200, loss: 0.11330, acc: 0.92935
# global step 14300, epoch: 1, batch: 14300, loss: 0.17803, acc: 0.92937
# global step 14400, epoch: 1, batch: 14400, loss: 0.11194, acc: 0.92945
# global step 14500, epoch: 1, batch: 14500, loss: 0.09886, acc: 0.92952
# global step 14600, epoch: 1, batch: 14600, loss: 0.58127, acc: 0.92959
# global step 14700, epoch: 1, batch: 14700, loss: 0.05974, acc: 0.92968
# global step 14800, epoch: 1, batch: 14800, loss: 0.03151, acc: 0.92981
# global step 14900, epoch: 1, batch: 14900, loss: 0.00516, acc: 0.92989
# global step 15000, epoch: 1, batch: 15000, loss: 0.15405, acc: 0.92999
# global step 15100, epoch: 1, batch: 15100, loss: 0.52067, acc: 0.93007
# global step 15200, epoch: 1, batch: 15200, loss: 0.44339, acc: 0.93011
# global step 15300, epoch: 1, batch: 15300, loss: 0.18534, acc: 0.93011
# global step 15400, epoch: 1, batch: 15400, loss: 0.06888, acc: 0.93022
# global step 15500, epoch: 1, batch: 15500, loss: 0.01719, acc: 0.93026
# global step 15600, epoch: 1, batch: 15600, loss: 0.48446, acc: 0.93033
# global step 15700, epoch: 1, batch: 15700, loss: 0.44657, acc: 0.93037
# global step 15800, epoch: 1, batch: 15800, loss: 0.30310, acc: 0.93034
# global step 15900, epoch: 1, batch: 15900, loss: 0.02225, acc: 0.93048
# global step 16000, epoch: 1, batch: 16000, loss: 0.03204, acc: 0.93056
# global step 16100, epoch: 1, batch: 16100, loss: 0.51840, acc: 0.93055
# global step 16200, epoch: 1, batch: 16200, loss: 0.08173, acc: 0.93066
# global step 16300, epoch: 1, batch: 16300, loss: 0.41935, acc: 0.93081
# global step 16400, epoch: 1, batch: 16400, loss: 0.02987, acc: 0.93092
# global step 16500, epoch: 1, batch: 16500, loss: 0.04806, acc: 0.93098
# global step 16600, epoch: 1, batch: 16600, loss: 0.06058, acc: 0.93102
# global step 16700, epoch: 1, batch: 16700, loss: 0.09893, acc: 0.93104
# global step 16800, epoch: 1, batch: 16800, loss: 0.00869, acc: 0.93110
# global step 16900, epoch: 1, batch: 16900, loss: 0.23287, acc: 0.93118
# global step 17000, epoch: 1, batch: 17000, loss: 0.23562, acc: 0.93129
# global step 17100, epoch: 1, batch: 17100, loss: 0.08820, acc: 0.93129
# global step 17200, epoch: 1, batch: 17200, loss: 0.05679, acc: 0.93135
# global step 17300, epoch: 1, batch: 17300, loss: 0.00716, acc: 0.93142
# global step 17400, epoch: 1, batch: 17400, loss: 0.14765, acc: 0.93148
# global step 17500, epoch: 1, batch: 17500, loss: 0.30070, acc: 0.93158
# global step 17600, epoch: 1, batch: 17600, loss: 0.24549, acc: 0.93166
# global step 17700, epoch: 1, batch: 17700, loss: 0.01511, acc: 0.93178
# global step 17800, epoch: 1, batch: 17800, loss: 0.03805, acc: 0.93185
# global step 17900, epoch: 1, batch: 17900, loss: 0.07475, acc: 0.93190
# global step 18000, epoch: 1, batch: 18000, loss: 0.32242, acc: 0.93189
# global step 18100, epoch: 1, batch: 18100, loss: 0.13089, acc: 0.93195
# global step 18200, epoch: 1, batch: 18200, loss: 0.17318, acc: 0.93201
# global step 18300, epoch: 1, batch: 18300, loss: 0.46486, acc: 0.93208
# global step 18400, epoch: 1, batch: 18400, loss: 0.31252, acc: 0.93214
# global step 18500, epoch: 1, batch: 18500, loss: 0.05160, acc: 0.93219
# global step 18600, epoch: 1, batch: 18600, loss: 0.28721, acc: 0.93221
# global step 18700, epoch: 1, batch: 18700, loss: 0.15902, acc: 0.93224
# global step 18800, epoch: 1, batch: 18800, loss: 0.05936, acc: 0.93230
# global step 18900, epoch: 1, batch: 18900, loss: 0.37548, acc: 0.93230
# global step 19000, epoch: 1, batch: 19000, loss: 0.03609, acc: 0.93240
# global step 19100, epoch: 1, batch: 19100, loss: 0.30973, acc: 0.93240
# global step 19200, epoch: 1, batch: 19200, loss: 0.19174, acc: 0.93250
# global step 19300, epoch: 1, batch: 19300, loss: 0.02678, acc: 0.93256
# global step 19400, epoch: 1, batch: 19400, loss: 0.88073, acc: 0.93263
# global step 19500, epoch: 1, batch: 19500, loss: 0.52220, acc: 0.93271
# global step 19600, epoch: 1, batch: 19600, loss: 0.04631, acc: 0.93280
# global step 19700, epoch: 1, batch: 19700, loss: 0.07466, acc: 0.93284
# global step 19800, epoch: 1, batch: 19800, loss: 0.01872, acc: 0.93289
# global step 19900, epoch: 1, batch: 19900, loss: 0.29953, acc: 0.93296
# global step 20000, epoch: 1, batch: 20000, loss: 0.50118, acc: 0.93300
# global step 20100, epoch: 1, batch: 20100, loss: 0.03579, acc: 0.93307
# global step 20200, epoch: 1, batch: 20200, loss: 0.21210, acc: 0.93315
# global step 20300, epoch: 1, batch: 20300, loss: 0.21824, acc: 0.93319
# global step 20400, epoch: 1, batch: 20400, loss: 0.07953, acc: 0.93328
# global step 20500, epoch: 1, batch: 20500, loss: 0.41012, acc: 0.93333
# global step 20600, epoch: 1, batch: 20600, loss: 0.04781, acc: 0.93337
# global step 20700, epoch: 1, batch: 20700, loss: 0.09294, acc: 0.93341
# global step 20800, epoch: 1, batch: 20800, loss: 0.08800, acc: 0.93339
# global step 20900, epoch: 1, batch: 20900, loss: 0.05138, acc: 0.93346
# global step 21000, epoch: 1, batch: 21000, loss: 0.25329, acc: 0.93351
# global step 21100, epoch: 1, batch: 21100, loss: 0.05152, acc: 0.93351
# global step 21200, epoch: 1, batch: 21200, loss: 0.36045, acc: 0.93359
# global step 21300, epoch: 1, batch: 21300, loss: 0.20953, acc: 0.93365
# global step 21400, epoch: 1, batch: 21400, loss: 0.09699, acc: 0.93372
# global step 21500, epoch: 1, batch: 21500, loss: 0.31606, acc: 0.93374
# global step 21600, epoch: 1, batch: 21600, loss: 0.20273, acc: 0.93376
# global step 21700, epoch: 1, batch: 21700, loss: 0.34345, acc: 0.93379
# global step 21800, epoch: 1, batch: 21800, loss: 0.12288, acc: 0.93387
# global step 21900, epoch: 1, batch: 21900, loss: 0.49497, acc: 0.93389
# global step 22000, epoch: 1, batch: 22000, loss: 0.03991, acc: 0.93393
# global step 22100, epoch: 1, batch: 22100, loss: 0.31713, acc: 0.93400
# global step 22200, epoch: 1, batch: 22200, loss: 0.47118, acc: 0.93402
# global step 22300, epoch: 1, batch: 22300, loss: 0.03581, acc: 0.93407
# global step 22400, epoch: 1, batch: 22400, loss: 0.08217, acc: 0.93412
# global step 22500, epoch: 1, batch: 22500, loss: 0.42208, acc: 0.93416
# global step 22600, epoch: 1, batch: 22600, loss: 0.20805, acc: 0.93414
# global step 22700, epoch: 1, batch: 22700, loss: 0.15036, acc: 0.93421
# global step 22800, epoch: 1, batch: 22800, loss: 0.04769, acc: 0.93429
# global step 22900, epoch: 1, batch: 22900, loss: 0.14400, acc: 0.93436
# global step 23000, epoch: 1, batch: 23000, loss: 0.40788, acc: 0.93437
# global step 23100, epoch: 1, batch: 23100, loss: 0.02667, acc: 0.93445
# global step 23200, epoch: 1, batch: 23200, loss: 0.22269, acc: 0.93448
# global step 23300, epoch: 1, batch: 23300, loss: 0.02271, acc: 0.93451
# global step 23400, epoch: 1, batch: 23400, loss: 0.01091, acc: 0.93460
# global step 23500, epoch: 1, batch: 23500, loss: 0.05518, acc: 0.93462
# global step 23600, epoch: 1, batch: 23600, loss: 0.21555, acc: 0.93466
# global step 23700, epoch: 1, batch: 23700, loss: 0.34463, acc: 0.93469
# global step 23800, epoch: 1, batch: 23800, loss: 0.21558, acc: 0.93475
# global step 23900, epoch: 1, batch: 23900, loss: 0.10232, acc: 0.93475
# global step 24000, epoch: 1, batch: 24000, loss: 0.01243, acc: 0.93484
# global step 24100, epoch: 1, batch: 24100, loss: 0.03078, acc: 0.93487
# global step 24200, epoch: 1, batch: 24200, loss: 0.03346, acc: 0.93495
# global step 24300, epoch: 1, batch: 24300, loss: 0.07065, acc: 0.93500
# global step 24400, epoch: 1, batch: 24400, loss: 0.02425, acc: 0.93499
# global step 24500, epoch: 1, batch: 24500, loss: 0.02206, acc: 0.93503
# global step 24600, epoch: 1, batch: 24600, loss: 0.31132, acc: 0.93504
# global step 24700, epoch: 1, batch: 24700, loss: 0.07943, acc: 0.93507
# global step 24800, epoch: 1, batch: 24800, loss: 0.08258, acc: 0.93511
# global step 24900, epoch: 1, batch: 24900, loss: 0.09041, acc: 0.93516
# global step 25000, epoch: 1, batch: 25000, loss: 0.35069, acc: 0.93522
# global step 25100, epoch: 1, batch: 25100, loss: 0.02054, acc: 0.93526
# global step 25200, epoch: 1, batch: 25200, loss: 0.02563, acc: 0.93528
# global step 25300, epoch: 1, batch: 25300, loss: 0.22944, acc: 0.93530
# global step 25400, epoch: 1, batch: 25400, loss: 0.15756, acc: 0.93535
# global step 25500, epoch: 1, batch: 25500, loss: 0.01319, acc: 0.93537
# global step 25600, epoch: 1, batch: 25600, loss: 0.35968, acc: 0.93537
# global step 25700, epoch: 1, batch: 25700, loss: 0.19400, acc: 0.93536
# global step 25800, epoch: 1, batch: 25800, loss: 0.51925, acc: 0.93538
# global step 25900, epoch: 1, batch: 25900, loss: 0.47441, acc: 0.93543
# global step 26000, epoch: 1, batch: 26000, loss: 0.10230, acc: 0.93542
# global step 26100, epoch: 1, batch: 26100, loss: 0.03469, acc: 0.93545
# global step 26200, epoch: 1, batch: 26200, loss: 0.05989, acc: 0.93548
# global step 26300, epoch: 1, batch: 26300, loss: 0.05009, acc: 0.93547
# global step 26400, epoch: 1, batch: 26400, loss: 0.06516, acc: 0.93549
# global step 26500, epoch: 1, batch: 26500, loss: 0.40809, acc: 0.93553
# global step 26600, epoch: 1, batch: 26600, loss: 0.12273, acc: 0.93559
# global step 26700, epoch: 1, batch: 26700, loss: 0.10325, acc: 0.93564
# global step 26800, epoch: 1, batch: 26800, loss: 0.07417, acc: 0.93566
# global step 26900, epoch: 1, batch: 26900, loss: 0.02758, acc: 0.93575
# global step 27000, epoch: 1, batch: 27000, loss: 0.16993, acc: 0.93578
# global step 27100, epoch: 1, batch: 27100, loss: 0.07418, acc: 0.93584
# global step 27200, epoch: 1, batch: 27200, loss: 0.13683, acc: 0.93587
# global step 27300, epoch: 1, batch: 27300, loss: 0.14642, acc: 0.93592
# global step 27400, epoch: 1, batch: 27400, loss: 0.21401, acc: 0.93595
# global step 27500, epoch: 1, batch: 27500, loss: 0.13512, acc: 0.93598
# global step 27600, epoch: 1, batch: 27600, loss: 0.46884, acc: 0.93602
# global step 27700, epoch: 1, batch: 27700, loss: 0.13923, acc: 0.93603
# global step 27800, epoch: 1, batch: 27800, loss: 0.03354, acc: 0.93606
# global step 27900, epoch: 1, batch: 27900, loss: 0.11666, acc: 0.93610
# global step 28000, epoch: 1, batch: 28000, loss: 0.43785, acc: 0.93615
# global step 28100, epoch: 1, batch: 28100, loss: 0.03287, acc: 0.93620
# global step 28200, epoch: 1, batch: 28200, loss: 0.18139, acc: 0.93620
# global step 28300, epoch: 1, batch: 28300, loss: 0.10423, acc: 0.93623
# global step 28400, epoch: 1, batch: 28400, loss: 0.10118, acc: 0.93624
# global step 28500, epoch: 1, batch: 28500, loss: 0.32322, acc: 0.93630
# global step 28600, epoch: 1, batch: 28600, loss: 0.20675, acc: 0.93631
# global step 28700, epoch: 1, batch: 28700, loss: 0.41376, acc: 0.93632
# global step 28800, epoch: 1, batch: 28800, loss: 0.03512, acc: 0.93635
# global step 28900, epoch: 1, batch: 28900, loss: 0.13410, acc: 0.93636
# global step 29000, epoch: 1, batch: 29000, loss: 0.11240, acc: 0.93638
# global step 29100, epoch: 1, batch: 29100, loss: 0.02619, acc: 0.93643
# global step 29200, epoch: 1, batch: 29200, loss: 0.05667, acc: 0.93647
# global step 29300, epoch: 1, batch: 29300, loss: 0.04616, acc: 0.93649
# global step 29400, epoch: 1, batch: 29400, loss: 0.27231, acc: 0.93651
# global step 29500, epoch: 1, batch: 29500, loss: 0.05241, acc: 0.93653
# global step 29600, epoch: 1, batch: 29600, loss: 0.09261, acc: 0.93654
# global step 29700, epoch: 1, batch: 29700, loss: 0.04953, acc: 0.93657
# global step 29800, epoch: 1, batch: 29800, loss: 0.04018, acc: 0.93661
# global step 29900, epoch: 1, batch: 29900, loss: 0.34165, acc: 0.93662
# global step 30000, epoch: 1, batch: 30000, loss: 0.03570, acc: 0.93668
# global step 30100, epoch: 1, batch: 30100, loss: 0.13845, acc: 0.93672
# global step 30200, epoch: 1, batch: 30200, loss: 0.06679, acc: 0.93676
# global step 30300, epoch: 1, batch: 30300, loss: 0.13828, acc: 0.93678
# global step 30400, epoch: 1, batch: 30400, loss: 0.07564, acc: 0.93680
# global step 30500, epoch: 1, batch: 30500, loss: 0.17826, acc: 0.93683
# global step 30600, epoch: 1, batch: 30600, loss: 0.11853, acc: 0.93684
# global step 30700, epoch: 1, batch: 30700, loss: 0.12339, acc: 0.93688
# global step 30800, epoch: 1, batch: 30800, loss: 0.12691, acc: 0.93689
# global step 30900, epoch: 1, batch: 30900, loss: 0.17982, acc: 0.93695
# global step 31000, epoch: 1, batch: 31000, loss: 0.01255, acc: 0.93699
# global step 31100, epoch: 1, batch: 31100, loss: 0.02237, acc: 0.93699
# global step 31200, epoch: 1, batch: 31200, loss: 0.03516, acc: 0.93697
# global step 31300, epoch: 1, batch: 31300, loss: 0.17838, acc: 0.93697
# global step 31400, epoch: 1, batch: 31400, loss: 0.04746, acc: 0.93701
# global step 31500, epoch: 1, batch: 31500, loss: 0.09210, acc: 0.93703
# global step 31600, epoch: 1, batch: 31600, loss: 0.02931, acc: 0.93703
# global step 31700, epoch: 1, batch: 31700, loss: 0.11264, acc: 0.93705
# global step 31800, epoch: 1, batch: 31800, loss: 0.09435, acc: 0.93705
# global step 31900, epoch: 1, batch: 31900, loss: 0.25611, acc: 0.93710
# global step 32000, epoch: 1, batch: 32000, loss: 0.31870, acc: 0.93710
# global step 32100, epoch: 1, batch: 32100, loss: 0.03618, acc: 0.93712
# global step 32200, epoch: 1, batch: 32200, loss: 0.03633, acc: 0.93714
# global step 32300, epoch: 1, batch: 32300, loss: 0.01014, acc: 0.93715
# global step 32400, epoch: 1, batch: 32400, loss: 0.15341, acc: 0.93718
# global step 32500, epoch: 1, batch: 32500, loss: 0.15632, acc: 0.93724
# global step 32600, epoch: 1, batch: 32600, loss: 0.26515, acc: 0.93725
# global step 32700, epoch: 1, batch: 32700, loss: 0.20244, acc: 0.93726
# global step 32800, epoch: 1, batch: 32800, loss: 0.76475, acc: 0.93729
# global step 32900, epoch: 1, batch: 32900, loss: 0.41081, acc: 0.93733
# global step 33000, epoch: 1, batch: 33000, loss: 0.07866, acc: 0.93736
# global step 33100, epoch: 1, batch: 33100, loss: 0.39065, acc: 0.93739
# global step 33200, epoch: 1, batch: 33200, loss: 0.45222, acc: 0.93741
# global step 33300, epoch: 1, batch: 33300, loss: 0.31611, acc: 0.93742
# global step 33400, epoch: 1, batch: 33400, loss: 0.24147, acc: 0.93743
# global step 33500, epoch: 1, batch: 33500, loss: 0.35486, acc: 0.93747
# global step 33600, epoch: 1, batch: 33600, loss: 0.55414, acc: 0.93749
# global step 33700, epoch: 1, batch: 33700, loss: 0.12893, acc: 0.93751
# global step 33800, epoch: 1, batch: 33800, loss: 0.02472, acc: 0.93752
# global step 33900, epoch: 1, batch: 33900, loss: 0.19778, acc: 0.93757
# global step 34000, epoch: 1, batch: 34000, loss: 0.00867, acc: 0.93760
# global step 34100, epoch: 1, batch: 34100, loss: 0.19353, acc: 0.93762
# global step 34200, epoch: 1, batch: 34200, loss: 0.26228, acc: 0.93763
# global step 34300, epoch: 1, batch: 34300, loss: 0.25498, acc: 0.93765
# global step 34400, epoch: 1, batch: 34400, loss: 0.07211, acc: 0.93766
# global step 34500, epoch: 1, batch: 34500, loss: 0.05744, acc: 0.93768
# global step 34600, epoch: 1, batch: 34600, loss: 0.01274, acc: 0.93770
# global step 34700, epoch: 1, batch: 34700, loss: 0.21199, acc: 0.93771
# global step 34800, epoch: 1, batch: 34800, loss: 0.23969, acc: 0.93774
# global step 34900, epoch: 1, batch: 34900, loss: 0.01880, acc: 0.93776
# global step 35000, epoch: 1, batch: 35000, loss: 0.18479, acc: 0.93776
# global step 35100, epoch: 1, batch: 35100, loss: 0.27668, acc: 0.93781
# global step 35200, epoch: 1, batch: 35200, loss: 0.03397, acc: 0.93780
# global step 35300, epoch: 1, batch: 35300, loss: 0.02516, acc: 0.93781
# global step 35400, epoch: 1, batch: 35400, loss: 0.10851, acc: 0.93784
# global step 35500, epoch: 1, batch: 35500, loss: 0.10632, acc: 0.93786
# global step 35600, epoch: 1, batch: 35600, loss: 0.28484, acc: 0.93790
# global step 35700, epoch: 1, batch: 35700, loss: 0.19103, acc: 0.93793
# global step 35800, epoch: 1, batch: 35800, loss: 0.05206, acc: 0.93793
# global step 35900, epoch: 1, batch: 35900, loss: 0.10995, acc: 0.93797
# global step 36000, epoch: 1, batch: 36000, loss: 0.02709, acc: 0.93800
# global step 36100, epoch: 1, batch: 36100, loss: 0.14596, acc: 0.93801
# global step 36200, epoch: 1, batch: 36200, loss: 0.38366, acc: 0.93801
# global step 36300, epoch: 1, batch: 36300, loss: 0.50913, acc: 0.93804
# global step 36400, epoch: 1, batch: 36400, loss: 0.37560, acc: 0.93804
# global step 36500, epoch: 1, batch: 36500, loss: 0.14472, acc: 0.93807
# global step 36600, epoch: 1, batch: 36600, loss: 0.28701, acc: 0.93806
# global step 36700, epoch: 1, batch: 36700, loss: 0.03556, acc: 0.93809
# global step 36800, epoch: 1, batch: 36800, loss: 0.15015, acc: 0.93810
# global step 36900, epoch: 1, batch: 36900, loss: 0.14346, acc: 0.93812
# global step 37000, epoch: 1, batch: 37000, loss: 0.02931, acc: 0.93816
# global step 37100, epoch: 1, batch: 37100, loss: 0.06836, acc: 0.93816
# global step 37200, epoch: 1, batch: 37200, loss: 0.03346, acc: 0.93817
# global step 37300, epoch: 1, batch: 37300, loss: 0.09864, acc: 0.93818
# global step 37400, epoch: 1, batch: 37400, loss: 0.26798, acc: 0.93823
# global step 37500, epoch: 1, batch: 37500, loss: 0.02619, acc: 0.93825
# global step 37600, epoch: 1, batch: 37600, loss: 0.13960, acc: 0.93828
# global step 37700, epoch: 1, batch: 37700, loss: 0.16819, acc: 0.93829
# global step 37800, epoch: 1, batch: 37800, loss: 0.08817, acc: 0.93831
# global step 37900, epoch: 1, batch: 37900, loss: 0.27013, acc: 0.93830
# global step 38000, epoch: 1, batch: 38000, loss: 0.15985, acc: 0.93830
# global step 38100, epoch: 1, batch: 38100, loss: 0.12247, acc: 0.93835
# global step 38200, epoch: 1, batch: 38200, loss: 0.10535, acc: 0.93837
# global step 38300, epoch: 1, batch: 38300, loss: 0.01312, acc: 0.93837
# global step 38400, epoch: 1, batch: 38400, loss: 0.31574, acc: 0.93838
# global step 38500, epoch: 1, batch: 38500, loss: 0.11784, acc: 0.93842
# global step 38600, epoch: 1, batch: 38600, loss: 0.19514, acc: 0.93847
# global step 38700, epoch: 1, batch: 38700, loss: 0.26810, acc: 0.93849
# global step 38800, epoch: 1, batch: 38800, loss: 0.09561, acc: 0.93853
# global step 38900, epoch: 1, batch: 38900, loss: 0.04417, acc: 0.93857
# global step 39000, epoch: 1, batch: 39000, loss: 0.01563, acc: 0.93861
# global step 39100, epoch: 1, batch: 39100, loss: 0.31766, acc: 0.93866
# global step 39200, epoch: 1, batch: 39200, loss: 0.43072, acc: 0.93870
# global step 39300, epoch: 1, batch: 39300, loss: 0.04083, acc: 0.93872
# global step 39400, epoch: 1, batch: 39400, loss: 0.21942, acc: 0.93875
# global step 39500, epoch: 1, batch: 39500, loss: 0.13169, acc: 0.93879
# global step 39600, epoch: 1, batch: 39600, loss: 0.39145, acc: 0.93880
# global step 39700, epoch: 1, batch: 39700, loss: 0.40754, acc: 0.93882
# global step 39800, epoch: 1, batch: 39800, loss: 0.40694, acc: 0.93884
# global step 39900, epoch: 1, batch: 39900, loss: 0.12134, acc: 0.93886
# global step 40000, epoch: 1, batch: 40000, loss: 0.07277, acc: 0.93887
# global step 40100, epoch: 1, batch: 40100, loss: 0.16900, acc: 0.93888
# global step 40200, epoch: 1, batch: 40200, loss: 0.29409, acc: 0.93888
# global step 40300, epoch: 1, batch: 40300, loss: 0.03856, acc: 0.93890
# global step 40400, epoch: 1, batch: 40400, loss: 0.02445, acc: 0.93893
# global step 40500, epoch: 1, batch: 40500, loss: 0.19339, acc: 0.93895
# global step 40600, epoch: 1, batch: 40600, loss: 0.19885, acc: 0.93897
# global step 40700, epoch: 1, batch: 40700, loss: 0.07454, acc: 0.93900
# global step 40800, epoch: 1, batch: 40800, loss: 0.24219, acc: 0.93901
# global step 40900, epoch: 1, batch: 40900, loss: 0.23404, acc: 0.93903
# global step 41000, epoch: 1, batch: 41000, loss: 0.11677, acc: 0.93905
# global step 41100, epoch: 1, batch: 41100, loss: 0.09116, acc: 0.93907
# global step 41200, epoch: 1, batch: 41200, loss: 0.02964, acc: 0.93910
# global step 41300, epoch: 1, batch: 41300, loss: 0.04183, acc: 0.93911
# global step 41400, epoch: 1, batch: 41400, loss: 0.02429, acc: 0.93913
# global step 41500, epoch: 1, batch: 41500, loss: 0.16047, acc: 0.93915
# global step 41600, epoch: 1, batch: 41600, loss: 0.07081, acc: 0.93916
# global step 41700, epoch: 1, batch: 41700, loss: 0.27757, acc: 0.93917
# global step 41800, epoch: 1, batch: 41800, loss: 0.10341, acc: 0.93919
# global step 41900, epoch: 1, batch: 41900, loss: 0.15752, acc: 0.93924
# global step 42000, epoch: 1, batch: 42000, loss: 0.48935, acc: 0.93923
# global step 42100, epoch: 1, batch: 42100, loss: 0.50689, acc: 0.93924
# global step 42200, epoch: 1, batch: 42200, loss: 0.20784, acc: 0.93925
# global step 42300, epoch: 1, batch: 42300, loss: 0.74701, acc: 0.93928
# global step 42400, epoch: 1, batch: 42400, loss: 0.01323, acc: 0.93931
# global step 42500, epoch: 1, batch: 42500, loss: 0.12688, acc: 0.93934
# global step 42600, epoch: 1, batch: 42600, loss: 0.20437, acc: 0.93938
# global step 42700, epoch: 1, batch: 42700, loss: 0.18941, acc: 0.93940
# global step 42800, epoch: 1, batch: 42800, loss: 0.35261, acc: 0.93943
# global step 42900, epoch: 1, batch: 42900, loss: 0.27056, acc: 0.93946
# global step 43000, epoch: 1, batch: 43000, loss: 0.01208, acc: 0.93949
# global step 43100, epoch: 1, batch: 43100, loss: 0.23707, acc: 0.93951
# global step 43200, epoch: 1, batch: 43200, loss: 0.02387, acc: 0.93952
# global step 43300, epoch: 1, batch: 43300, loss: 0.47914, acc: 0.93952
# global step 43400, epoch: 1, batch: 43400, loss: 0.15815, acc: 0.93951
# global step 43500, epoch: 1, batch: 43500, loss: 0.17593, acc: 0.93951
# global step 43600, epoch: 1, batch: 43600, loss: 0.02723, acc: 0.93950
# global step 43700, epoch: 1, batch: 43700, loss: 0.00753, acc: 0.93953
# global step 43800, epoch: 1, batch: 43800, loss: 0.07509, acc: 0.93955
# global step 43900, epoch: 1, batch: 43900, loss: 0.04418, acc: 0.93955
# global step 44000, epoch: 1, batch: 44000, loss: 0.08975, acc: 0.93958
# global step 44100, epoch: 1, batch: 44100, loss: 0.47578, acc: 0.93960
# global step 44200, epoch: 1, batch: 44200, loss: 0.22777, acc: 0.93962
# global step 44300, epoch: 1, batch: 44300, loss: 0.52604, acc: 0.93960
# global step 44400, epoch: 1, batch: 44400, loss: 0.45989, acc: 0.93962
# global step 44500, epoch: 1, batch: 44500, loss: 0.17279, acc: 0.93963
# global step 44600, epoch: 1, batch: 44600, loss: 0.16859, acc: 0.93964
# global step 44700, epoch: 1, batch: 44700, loss: 0.05148, acc: 0.93966
# global step 44800, epoch: 1, batch: 44800, loss: 0.01589, acc: 0.93969
# global step 44900, epoch: 1, batch: 44900, loss: 0.12593, acc: 0.93970
# global step 45000, epoch: 1, batch: 45000, loss: 0.07079, acc: 0.93972
# global step 45100, epoch: 1, batch: 45100, loss: 0.28238, acc: 0.93972
# global step 45200, epoch: 1, batch: 45200, loss: 0.02068, acc: 0.93975
# global step 45300, epoch: 1, batch: 45300, loss: 0.20431, acc: 0.93976
# global step 45400, epoch: 1, batch: 45400, loss: 0.20354, acc: 0.93975
# global step 45500, epoch: 1, batch: 45500, loss: 0.33854, acc: 0.93974
# global step 45600, epoch: 1, batch: 45600, loss: 0.01705, acc: 0.93974
# global step 45700, epoch: 1, batch: 45700, loss: 0.57303, acc: 0.93977
# global step 45800, epoch: 1, batch: 45800, loss: 0.06393, acc: 0.93977
# global step 45900, epoch: 1, batch: 45900, loss: 0.07707, acc: 0.93980
# global step 46000, epoch: 1, batch: 46000, loss: 0.06682, acc: 0.93980
# global step 46100, epoch: 1, batch: 46100, loss: 0.44782, acc: 0.93981
# global step 46200, epoch: 1, batch: 46200, loss: 0.32222, acc: 0.93982
# global step 46300, epoch: 1, batch: 46300, loss: 0.27770, acc: 0.93983
# global step 46400, epoch: 1, batch: 46400, loss: 0.09304, acc: 0.93984
# global step 46500, epoch: 1, batch: 46500, loss: 0.32458, acc: 0.93985
# global step 46600, epoch: 1, batch: 46600, loss: 0.01797, acc: 0.93986
# global step 46700, epoch: 1, batch: 46700, loss: 0.35008, acc: 0.93985
# global step 46800, epoch: 1, batch: 46800, loss: 0.03765, acc: 0.93986
# global step 46900, epoch: 1, batch: 46900, loss: 0.03621, acc: 0.93987
# global step 47000, epoch: 1, batch: 47000, loss: 0.01410, acc: 0.93992
# eval loss: 0.11553, accu: 0.96206
# 0.9620625

# %%
# 최종모델 업로드 (예측 모델 적용)          
params_path = 'checkpoint/model_state.pdparams'        
if params_path and os.path.isfile(params_path):  
    state_dict = paddle.load(params_path)
    model.set_dict(state_dict)
    print("Loaded parameters from %s" % params_path)
# Out:
# Loaded parameters from checkpoint/model_state.pdparams

# %% [markdown]
# ## 5-3 모델 평가

# %%
# 검증데이터 평가 
evaluate(model, criterion, metric, dev_data_loader)
# Out:
# eval loss: 0.11553, accu: 0.96206
# 0.9620625

# %% [markdown]
# #6 프로젝트 결론 및 향후 개선점

# %%
#모델 예측(테스트 데이터 적용)
def predict(model, data, tokenizer, label_map, batch_size=1):
    examples = []
    # 모델에 적용하기 위한 테스트데이터 함수화 
    for text in data:
        input_ids, segment_ids = convert_example(
            text,
            tokenizer,
            max_seq_length=48,
            is_test=True)
        examples.append((input_ids, segment_ids))

    batchify_fn = lambda samples, fn=Tuple(
        Pad(axis=0, pad_val=tokenizer.pad_token_id),  # input id
        Pad(axis=0, pad_val=tokenizer.pad_token_id),  # segment id
    ): fn(samples)

    # cf) Seperates data into some batches.
    batches = []
    one_batch = []
    for example in examples:
        one_batch.append(example)
        if len(one_batch) == batch_size:
            batches.append(one_batch)
            one_batch = []
    if one_batch:
        # cf) The last batch whose size is less than the config batch_size setting.
        batches.append(one_batch)

    results = []
    model.eval()
    for batch in batches:
        input_ids, segment_ids = batchify_fn(batch)
        input_ids = paddle.to_tensor(input_ids)
        segment_ids = paddle.to_tensor(segment_ids)
        logits = model(input_ids, segment_ids)
        probs = F.softmax(logits, axis=1)
        idx = paddle.argmax(probs, axis=1).numpy()
        idx = idx.tolist()
        labels = [label_map[i] for i in idx]
        results.extend(labels)
    return results

# %%
# 테스트 데이터 적용 라벨(리스트) 맵
label_map = {0: '科技', 1: '体育', 2: '时政', 3: '股票', 4: '娱乐', 5: '教育', 6: '家居', 7: '财经', 8: '房产', 9: '社会', 10: '游戏', 11: '彩票', 12: '星座', 13: '时尚'}
print(label_map)
# Out:
# {0: '科技', 1: '体育', 2: '时政', 3: '股票', 4: '娱乐', 5: '教育', 6: '家居', 7: '财经', 8: '房产', 9: '社会', 10: '游戏', 11: '彩票', 12: '星座', 13: '时尚'}

# %%
# 테스트데이터 df화
df_test = pd.read_csv('./df_test.csv', sep='\t')  
df_test
# Out:
#                               text
# 0          北京君太百货璀璨秋色 满100省353020元
# 1                教育部：小学高年级将开始学习性知识
# 2            专业级单反相机 佳能7D单机售价9280元
# 3              星展银行起诉内地客户 银行强硬客户无奈
# 4           脱离中国的实际 强压人民币大幅升值只能是梦想
# ...                            ...
# 83594        Razer杯DotA精英挑战赛8月震撼登场
# 83595              经济数据好转吹散人民币贬值预期
# 83596         抵押率抵押物双控政策 刘明康支招房产贷款
# 83597  8000万像素 利图发布Aptus-II 12数码后背
# 83598          教育部公布33个国家万余所正规学校名单
#
# [83599 rows x 1 columns]

# %%
# 예측모델에 적용하기 위한 테스트데이터 전처리
def preprocess_prediction_data(data):
    examples = []
    for text in data:
        examples.append({"text": text})
    return examples

test_data = df_test['text']
df_test = preprocess_prediction_data(test_data)

# %%
# 테스트 데이터 모델링
results = predict(model, df_test, tokenizer, label_map, batch_size=16)

# %%
# 예측 결과 txt 문서화
def write_results(labels, file_path):
    with open(file_path, "w", encoding="utf8") as f:
        f.writelines("\n".join(labels))

write_results(results, "/content/drive/MyDrive/AI_Bootcamp/Project1_Data/result.txt")

# %%
df_test2 = pd.read_table('/content/drive/MyDrive/AI_Bootcamp/Project1_Data/test.txt', sep='\t', header=None)
df_test2.columns = ['text']
print(df_test2)
# Out:
#                               text
# 0          北京君太百货璀璨秋色 满100省353020元
# 1                教育部：小学高年级将开始学习性知识
# 2            专业级单反相机 佳能7D单机售价9280元
# 3              星展银行起诉内地客户 银行强硬客户无奈
# 4           脱离中国的实际 强压人民币大幅升值只能是梦想
# ...                            ...
# 83594        Razer杯DotA精英挑战赛8月震撼登场
# 83595              经济数据好转吹散人民币贬值预期
# 83596         抵押率抵押物双控政策 刘明康支招房产贷款
# 83597  8000万像素 利图发布Aptus-II 12数码后背
# 83598          教育部公布33个国家万余所正规学校名单
#
# [83599 rows x 1 columns]

# %%
results = pd.read_table("/content/drive/MyDrive/AI_Bootcamp/Project1_Data/result.txt", sep='\t', header=None)
results.columns = ['label']
print(results)
# Out:
#       label
# 0        家居
# 1        时政
# 2        科技
# 3        股票
# 4        股票
# ...     ...
# 83594    游戏
# 83595    股票
# 83596    房产
# 83597    科技
# 83598    教育
#
# [83599 rows x 1 columns]

# %%
test_predict = pd.concat([df_test2, results],axis=1)
print(test_predict)
# Out:
#                               text label
# 0          北京君太百货璀璨秋色 满100省353020元    家居
# 1                教育部：小学高年级将开始学习性知识    时政
# 2            专业级单反相机 佳能7D单机售价9280元    科技
# 3              星展银行起诉内地客户 银行强硬客户无奈    股票
# 4           脱离中国的实际 强压人民币大幅升值只能是梦想    股票
# ...                            ...   ...
# 83594        Razer杯DotA精英挑战赛8月震撼登场    游戏
# 83595              经济数据好转吹散人民币贬值预期    股票
# 83596         抵押率抵押物双控政策 刘明康支招房产贷款    房产
# 83597  8000万像素 利图发布Aptus-II 12数码后背    科技
# 83598          教育部公布33个国家万余所正规学校名单    教育
#
# [83599 rows x 2 columns]

# %% [markdown]
# ##6-1 테스트 데이터 주제 매칭

# %%
test_predict.to_csv('test_predict.txt', sep = '\t')
test_predict.head(50)
# Out:
#                            text label
# 0       北京君太百货璀璨秋色 满100省353020元    家居
# 1             教育部：小学高年级将开始学习性知识    时政
# 2         专业级单反相机 佳能7D单机售价9280元    科技
# 3           星展银行起诉内地客户 银行强硬客户无奈    股票
# 4        脱离中国的实际 强压人民币大幅升值只能是梦想    股票
# 5         内城土地稀缺 对开发商提出更高要求(组图)    房产
# 6           亚欧首脑会议举行第二次全体会议(组图)    时政
# 7      荷兰主帅球迷面前表决心耍酷 罗本不在范佩西成一哥    体育
# 8     搭配18-105VR镜头 尼康D90带票7109元    科技
# 9       百盛购物中心美罗城店 同一专柜花120得200    家居
# 10          陈水扁获释后首次出庭控告他人诽谤(图)    时政
# 11       为艺术喝彩 索尼推出限量珍藏NWD-W202    科技
# 12       新一轮价格战的开端？昂达VX530仅299元    科技
# 13            三星数码相框迎圣诞送好礼活动促销中    科技
# 14    魔兽33+11魔术克尼克斯 雷霆压爵士捍卫赛区榜首    体育
# 15                杭州经济适用房被曝质量问题    房产
# 16              欧元区在希腊援助条款上出现分歧    股票
# 17      入门级单反相机 尼康D3100促销价4060元    科技
# 18             盖特纳：解决希腊问题时间所剩无几    股票
# 19                骗子冒充北京干部骗财24万    社会
# 20   2010年韩国影展开幕 观众可体验“4D”效果(图)    娱乐
# 21           亨通光电：行业景气下滑 未来仍有看点    股票
# 22    美媒：内内下份合同值5000万 留在掘金能打大前锋    体育
# 23       刘明康：严格实施二套房政策 防范房产金融风险    房产
# 24         莎拉-杰西卡-帕克有意拍摄《欲望都市3》    娱乐
# 25      带伤大郅仍是江苏头号公敌 主帅：防住了他就能赢    体育
# 26            全国5.6万名军队转业干部安置完成    时政
# 27              法国总理菲永称希望修复对华关系    时政
# 28          欧洲三大股市下跌 英国股市跌0.18%    股票
# 29     2.8英寸液晶屏 iriver E200仅699    科技
# 30   美国3月ISM制造业指数为59.6 前值为56.5     股票
# 31                    台股全日跌2.4%    股票
# 32          纽约黄金期货收盘上涨1% 期铜大涨7%    股票
# 33                  将浴缸里的水排尽(图)    家居
# 34          精钢打造，金属质感迈德克斯MS-830    科技
# 35    支持10倍光变 松下MD10000GK仅售6899    科技
# 36     前瞻-苏粤大战NBA外援成变数 郭艾伦对位马布里    体育
# 37        芝加哥影评人协会奖提名《社交网战》一家独大    科技
# 38  美国6月ISM制造业指数为56.2% 前值为59.7     股票
# 39           美国上周初请失业金人数为55.4万     股票
# 40      老师罚14岁女生做200个下蹲 称让其锻炼身体    社会
# 41         棕榈园林：积极稳健的踏上园林综合发展之路    房产
# 42           招商银行：贷款稳增 同业资产大幅增加    股票
# 43                 门是以雕花作为造型(图)    家居
# 44       环球雅思张永琪：留学“增值服务”特色(组图)    教育
# 45    西班牙新宠克服离家恐惧症 25岁新星至今不敢考驾照    体育
# 46                 揭密芙蓉姐姐的家(组图)    家居
# 47           华锐铸钢：风电竞争激烈 锻件刚刚开始    股票
# 48              澳际明日之星：有梦想你就是天才    娱乐
# 49        浙江阳光：业绩略低于预期 节能照明推广加速    股票

# %%
test_predict = pd.DataFrame(test_predict)
test_predict.to_csv('/content/drive/MyDrive/AI_Bootcamp/Project1_Data/test_predict.csv', header=False, index=True)

# %% [markdown]
# ## 6-2  결론
#
# ### 0 . 기존에 배웠던 딥러닝 프레임 워크 이외에 Paddle-Paddle이라는 새로운 딥러닝 프레임 워크를 사용해 프로젝트를 수행하는 과정에서 프레임 워크 간, 작동 차이점에 대한 기초적인 이해를 할 수 있었다.
#
# ### 1. Robert 사전 모델을 사용해, 사전 모델을 적용할 경우 모델의 성능을 기본적으로 높일 수 있었다.

# %% [markdown]
# ## 6-3 프로젝트 한계점 및 향후 개선점
#
# ### 1. 테스트 데이터의 실제 라벨이 주어지지 않은 데이터를 사용해 테스트셋의 모델 적용 결과에 대한 성능 지표를 확인하지 못했다.
#
# ### 2. 프로젝트 진행 간 시각화 등의 추가적인 이해 요소가 추가되지 못했다. 추후에 성능 지표 시각화 및 프로젝트 결과물에 대한 추가적인 설명이 담긴 이미지를 첨부할 예정이다.
